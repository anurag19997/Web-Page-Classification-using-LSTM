# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
train=pd.read_csv('train.csv')
train.set_index('Webpage_id',inplace=True)
test=pd.read_csv('test_nvPHrOx.csv')
test.set_index('Webpage_id',inplace=True)
submission=pd.read_csv('sample_submission_poy1UIu.csv')

# %%
train.head(35)
# Out:
#                           Domain  \
# Webpage_id
# 1           www.fiercepharma.com
# 2           www.fiercepharma.com
# 3           www.fiercepharma.com
# 4           www.fiercepharma.com
# 5           www.fiercepharma.com
# 6           www.fiercepharma.com
# 7           www.fiercepharma.com
# 8           www.fiercepharma.com
# 9           www.fiercepharma.com
# 10          www.fiercepharma.com
# 11          www.fiercepharma.com
# 12          www.fiercepharma.com
# 13          www.fiercepharma.com
# 14          www.fiercepharma.com
# 15          www.fiercepharma.com
# 16          www.fiercepharma.com
# 17          www.fiercepharma.com
# 18          www.fiercepharma.com
# 19          www.fiercepharma.com
# 20          www.fiercepharma.com
# 21          www.fiercepharma.com
# 22          www.fiercepharma.com
# 23          www.fiercepharma.com
# 24          www.fiercepharma.com
# 25          www.fiercepharma.com
# 26          www.fiercepharma.com
# 27          www.fiercepharma.com
# ...

# %%
test.head()
# Out:
#                                    Domain  \
# Webpage_id
# 31                             isrctn.com
# 32          www.clinicaltrialsregister.eu
# 33          www.clinicaltrialsregister.eu
# 34          www.clinicaltrialsregister.eu
# 35          www.clinicaltrialsregister.eu
#
#                                                           Url
# Webpage_id
# 31                       http://www.isrctn.com/ISRCTN57801413
# 32          https://www.clinicaltrialsregister.eu/ctr-sear...
# 33          https://www.clinicaltrialsregister.eu/ctr-sear...
# 34          https://www.clinicaltrialsregister.eu/ctr-sear...
# 35          https://www.clinicaltrialsregister.eu/ctr-sear...

# %%
submission.head()
# Out:
#    Webpage_id   Tag
# 0          31  news
# 1          32  news
# 2          33  news
# 3          34  news
# 4          35  news

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53447 entries, 0 to 53446
# Data columns (total 4 columns):
# Webpage_id    53447 non-null int64
# Domain        53447 non-null object
# Url           53447 non-null object
# Tag           53447 non-null object
# dtypes: int64(1), object(3)
# memory usage: 1.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25787 entries, 0 to 25786
# Data columns (total 3 columns):
# Webpage_id    25787 non-null int64
# Domain        25787 non-null object
# Url           25787 non-null object
# dtypes: int64(1), object(2)
# memory usage: 604.5+ KB

# %%
len(train.Domain.unique())
# Out:
# 3974

# %%
len(train.Tag.unique())
# Out:
# 9

# %%
train.Tag.unique()
# Out:
# array(['news', 'clinicalTrials', 'conferences', 'profile', 'forum',
#        'publication', 'thesis', 'guidelines', 'others'], dtype=object)

# %%
plt.figure(1)
plt.subplot(424)
train.Tag.value_counts(normalize=False).plot.bar(figsize=(20,20),title='Tag')

# %%
import zipfile

zf = zipfile.ZipFile('train.zip') 
df = pd.read_csv(zf.open('html_data.csv'),chunksize=1)

# %%
print(df)

# %%
chunksize = 1000
for chunk in pd.read_csv(zf.open('html_data.csv'), chunksize=chunksize):
    print(chunk)
# Out:
#      Webpage_id                                               Html
# 0             1  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 1             2  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 2             3  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 3             4  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 4             5  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 5             6  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 6             7  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 7             8  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 8             9  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 9            10  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 10           11  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 11           12  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# 12           13  <!DOCTYPE html>\n<html lang="en" dir="ltr" xml...
# ...

# %%
a=chunk[chunk.Webpage_id==11001].Webpage_id
#a.Webpage_id

# %%
a.iloc[0]
# Out:
# 11001

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
a
# Out:
# 79300    \r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n\t<head>\r\n        <title>Victor Alcade, M.D. | Aria Health Care</title>\r\n        <meta name="description" content="Dr. Victor Alcade, M.D. practices Emergency Medicine and is affiliated with Aria Health Care in Philadelphia, PA." />\r\n        <meta id="provDescription_MD" itemprop="description" content="Dr. Victor Alcade, M.D. practices Emergency Medicine and is affiliated with Aria Health Care in Philadelphia, PA." />\r\n    <meta content="text/html; charset=utf-8" http-equiv="Content-Type" />\r\n\r\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n\t\t<link rel="shortcut icon" href="/Content/CustomViewsContent/_Shared/images/favicon.ico" />\r\n\r\n\t\t\r\n\t\t<link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,400italic,700,700italic,300italic" rel="stylesheet" type="text/css" />\r\n\r\n\t\t<script data-num-accounts="1" id="gaScript" type=
# ...

# %%
plt.figure(1)
plt.subplot(424)
train.Domain.value_counts(normalize=False).plot.bar(figsize=(20,20),title='Domain')

# %%
len(train.Domain.unique())
# Out:
# 3974

# %%
len(set(train.Domain))
# Out:
# 3974

# %%
a=set(train.Domain)
b=set(test.Domain)
len(a.intersection(b))
# Out:
# 578

# %%
import re
pattern=r'<title>.*</title>'
c=re.findall(pattern,a.iloc[0])

# %%
c[0][7:-7]
# Out:
# ' Surgical menopause...Yes, estrogen is low 4 years later...  | No Uterus - No Ovaries - No Hormones - Managing Menopause | HysterSisters<'

# %%
z=[]
z.append(['hi',1])

# %%
z.append(['hii',2])

# %%
z
# Out:
# [['hi', 1], ['hii', 2]]

# %%
m=[]
len(m)
# Out:
# 0
